# %% [markdown]
# ### 多元线性回归

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# def train_test_split(ylabel, random_state=1):
#     import random 
#     index=random.sample(range(len(ylabel)),50*random_state)
#     list_train=[]
#     list_test=[]
#     i=0
#     for s in range(len(ylabel)):
#         if i in index:
#             list_test.append(i)
#         else:
#             list_train.append(i)
#         i+=1
#     return list_train,list_test


# read csv files
data = pd.read_csv('./Advertising.csv')
feature_cols = ['TV', 'radio', 'newspaper']
X = data[feature_cols]
y = data['sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)
linreg = LinearRegression()
model = linreg.fit(X_train, y_train)
print(model)
print(linreg.intercept_)
print(linreg.coef_)

# root mean square error
y_pred = linreg.predict(X_test)
length = len(y_pred)
sum_mean = 0
for i in range(length):
    sum_mean += (y_pred[i]-y_test.values[i])**2
error = np.sqrt(sum_mean/length)
print("error:%f" % error)

# roc curve
plt.figure()
plt.plot(np.arange(length), y_pred, 'r', label='predict')
plt.plot(np.arange(length), y_test, 'b', label='test')
plt.legend(loc='upper right')
plt.xlabel("number of scale")
plt.ylabel("value")
plt.show()
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# 2.87696662231793
# [0.04656457 0.17915812 0.00345046]
# error:1.404651
